# %% [markdown]
# # Analysis

# %%
from ostatslib.agents import PPOAgent
from sklearn.datasets import make_classification
from pandas import DataFrame

import warnings
warnings.filterwarnings('ignore')

# loading trained agent
agent = PPOAgent('../trained_ppo_model.zip')

# generating data
X, y = make_classification()
classification_data = DataFrame(X)
classification_data['result'] = y

# running analysis
classification_analysis = agent.analyze(classification_data)

# printing results
print(classification_analysis.summary())
# Out:
# Analysis executed at 2023-06-07 23:08:16.534452
# Final status is Complete
# Initial State known features:
#
# Steps:
#   Order  Step                                      Reward  State Change
# -------  --------------------------------------  --------  --------------------------------------
#       1  Infer Response DType                         0.5  response_inferred_dtype  integer
#       2  Is Response Positive Values Only Check       0.5  is_response_positive_values_only  1
#       3  Is Response Quantitative Check               0.5  is_response_quantitative  1
#       4  Is Response Discrete Check                   0.5  is_response_discrete  1
#       5  Is Response Dichotomous Check                0.5  is_response_dichotomous  1
#       6  Get Log Rows Count                           0.5  log_rows_count  0.386399
#       7  Logistic Regression                          1    score                             0.98
#                                                            logistic_regression_score_reward  0.98

# %%
from sklearn.datasets import make_regression

# generating data
X, y = make_regression()
regression_data = DataFrame(X)
regression_data['result'] = y

# running analysis
regression_analysis = agent.analyze(regression_data)

# printing results
print(regression_analysis.summary())
# Out:
# Analysis executed at 2023-06-07 23:08:20.241569
# Final status is Complete
# Initial State known features:
#
# Steps:
#   Order  Step                                Reward  State Change
# -------  --------------------------------  --------  --------------------------------------------------------------
#       1  Infer Response DType                   0.5  response_inferred_dtype  floating
#       2  Get Response Unique Values Ratio       0.5  response_unique_values_ratio  1
#       3  Time Convertible Variable Search       0.5  time_convertible_variable
#       4  Is Response Dichotomous Check          0.5  is_response_dichotomous  -1
#       5  Is Response Quantitative Check         0.5  is_response_quantitative  1
#       6  Get Log Rows Count                     0.5  log_rows_count  0.386399
#       7  Is Response Discrete Check             0.5  is_response_discrete  -1
#       8  Linear Regression                      0.6  score                                                        1
#                                                      are_linear_model_regression_residuals_correlated            -1
#                                                      are_linear_model_regression_residuals_heteroscedastic       -1
#                                                      are_linear_model_regression_residuals_normally_distributed   1
#                                                      is_linear_model_regression_recursive_residuals_mean_zero    -1
#                                                      linear_regression_score_reward                               1

# %%
from sklearn.datasets import load_breast_cancer
from ostatslib.states import State

# generating data
x_dataframe, y_series = load_breast_cancer(return_X_y=True, as_frame=True)
breast_cancer_data = x_dataframe.join(y_series)

breast_cancer_data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness
# 0        17.99         10.38          122.80     1001.0          0.11840  \
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry
# 0           0.27760          0.3001              0.14710         0.2419  \
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area
# 0                 0.07871  ...          17.33           184.60      2019.0  \
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points
# 0            0.1622             0.6656           0.7119                0.2654  \
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
breast_cancer_state = State()
breast_cancer_state.set('response_variable_label', y_series.name)

# running analysis
breast_cancer_analysis = agent.analyze(breast_cancer_data, breast_cancer_state)

# printing results
print(breast_cancer_analysis.summary())
# Out:
# Analysis executed at 2023-06-07 23:08:27.920330
# Final status is Complete
# Initial State known features:
# response_variable_label  target
# Steps:
#   Order  Step                                      Reward  State Change
# -------  --------------------------------------  --------  ------------------------------------------
#       1  Infer Response DType                         0.5  response_inferred_dtype  integer
#       2  Is Response Positive Values Only Check       0.5  is_response_positive_values_only  1
#       3  Is Response Quantitative Check               0.5  is_response_quantitative  1
#       4  Is Response Discrete Check                   0.5  is_response_discrete  1
#       5  Is Response Dichotomous Check                0.5  is_response_dichotomous  1
#       6  Get Log Rows Count                           0.5  log_rows_count  0.532286
#       7  Logistic Regression                          1    score                             0.961336
#                                                            logistic_regression_score_reward  0.961336

# %%
from ostatslib.environments.utils._generate_from_pmlb import generate_from_pmlb

data, state = generate_from_pmlb()

analysis = agent.analyze(data, state)

# printing results
print(data.info())
print(analysis.summary())
# Out:
# SVR() (100, 5) 100
# SVR(C=10) 0.7424538568812749
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   oz1     100 non-null    float64
#  1   oz2     100 non-null    float64
#  2   oz3     100 non-null    float64
#  3   oz4     100 non-null    float64
#  4   oz5     100 non-null    float64
#  5   target  100 non-null    float64
# dtypes: float64(6)
# memory usage: 4.8 KB
# None
#
# Analysis executed at 2023-06-07 23:19:38.322738
# Final status is Complete
# Initial State known features:
# response_variable_label  target
# Steps:
#   Order  Step                                 Reward  State Change
# -------  --------------------------------  ---------  -------------------------------------------------------------------
#       1  Infer Response DType               0.5       response_inferred_dtype  floating
#       2  Get Response Unique Values Ratio   0.5       response_unique_values_ratio  1
#       3  Time Convertible Variable Search   0.5       time_convertible_variable
#       4  Is Response Dichotomous Check      0.5       is_response_dichotomous  -1
#       5  Is Response Quantitative Check     0.5       is_response_quantitative  1
#       6  Get Log Rows Count                 0.5       log_rows_count  0.386399
#       7  Is Response Discrete Check         0.5       is_response_discrete  -1
#       8  Linear Regression                 -1         score                                                        0.3387
#                                                       are_linear_model_regression_residuals_correlated             1
#                                                       are_linear_model_regression_residuals_heteroscedastic       -0.5
#                                                       are_linear_model_regression_residuals_normally_distributed   0.5
#                                                       is_linear_model_regression_recursive_residuals_mean_zero     1
#                                                       linear_regression_score_reward                              -0.6613
#       9  Support Vector Regression          0.642454  score                                   0.742454
#                                                       support_vector_regression_score_reward  0.742454
